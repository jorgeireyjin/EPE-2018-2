# %% [markdown]
# ## Caso Demo 4: Práctica 1 - Uso de Sentencias Selectivas
#
# Una empresa de telecomunicaciones para sus equipos más vendidos lanza una nueva oferta comercial, con los siguientes precios:
#
# Tipo de Celular
#
# <table>
#     <tr>
#         <td>Tipo de Planes</td>
#         <td>Huawei</td>
#         <td>Iphone</td>
#         <td>Samsung</td>
#     </tr>
#     <tr>
#         <td>Plan Juvenil</td>
#         <td>20.00</td>
#         <td>25.00</td>
#         <td>23.00</td>
#     </tr>
#     <tr>
#         <td>Plan Negocio</td>
#         <td>30.00</td>
#         <td>34.00</td>
#         <td>32.00</td>
#     </tr>
#     <tr>
#         <td>Plan Empresarial</td>
#         <td>60.00</td>
#         <td>75.00</td>
#         <td>65.00</td>
#     </tr>
# </table>
#
# Si los clientes adquieren un plan por portabilidad, es decir, vienen de la operadora de la competencia, adicionalmente se le aplica un descuento dependiendo del equipo:
#
# <table>
#     <tr>
#         <td></td>
#         <td>Huawei</td>
#         <td>Iphone</td>
#         <td>Samsung</td>
#     </tr>
#     <tr>
#         <td>Descuento al plan</td>
#         <td>5%</td>
#         <td>7%</td>
#         <td>6%</td>
#     </tr>
# </table>
#
# Se pide:
# + Dado un tipo de equipo y plan, indicar el precio (4 puntos)
# +Indicar el descuento por portabilidad por equipo. (2 puntos)
# + Calcular el costo anual por tipo de equipo y plan. Considerar si el cliente viene de otra operadora, es decir, si aplica el descuento de portabilidad (Aplica el descuento de portabilidad si el parámetro es TRUE). (4 puntos)

# %%
def calcularPrecioMensual(celular, plan)

end

def calcularDescuento(celular)

end

def calcularTotalAnual(celular, plan, portabilidad)

end

#--- zona de test ----

def test_calcularPrecioMensual
    print validate(20.00, calcularPrecioMensual("Huawei","Juvenil")) 
	print validate(75.00, calcularPrecioMensual("Iphone","Empresarial")) 
	print validate(34.00, calcularPrecioMensual("Iphone","Negocio")) 
	print validate(65.00, calcularPrecioMensual("Samsung","Empresarial")) 
	print validate(23.00, calcularPrecioMensual("Samsung","Juvenil")) 
end

def test_calcularDescuento
    print validate(0.05, calcularDescuento("Huawei")) 
	print validate(0.07, calcularDescuento("Iphone")) 
	print validate(0.06, calcularDescuento("Samsung")) 
end

def test_calcularTotalAnual
    print validate(720.00, calcularTotalAnual("Huawei","Empresarial", false)) 
	print validate(279.00, calcularTotalAnual("Iphone","Juvenil", true)) 
	print validate(360.96, calcularTotalAnual("Samsung","Negocio", true)) 
end

def validate (expected, value)
 expected == value ? "." : "F"
end

def test
 
  
  puts "Test de prueba del programa"
  puts "---------------------------"
  test_calcularPrecioMensual
  test_calcularDescuento
  test_calcularTotalAnual
  puts " "
end
test
# Out:
# Test de prueba del programa
# ---------------------------
# FFFFFFFFFFF

# %% [markdown]
# #### Contactanos
# ![https://www.facebook.com/instructorenprogramacion/](qr.png "https://www.facebook.com/instructorenprogramacion/")
