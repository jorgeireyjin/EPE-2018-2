# %% [markdown]
# ## Caso Demo 2: Practica 1 - Sentencias Selectivas
# Promperú le ha contratado para que desarrolle un programa que permita agilizar las cotizaciones de paquetes a la Riviera Maya. Para ello le han proporcionado la siguiente información:
#
# COSTO DE PASAJE IDA Y VUELTA
# <table>
#     <tr>
#         <td>CODIGO</td>
#         <td>AEROLINEA</td>
#         <td>PRECIO x PERSONA $</td>
#         <td>VIA</td>
#     </tr>
#     <tr>
#         <td>MX</td>
#         <td>Aeroméxico</td>
#         <td>580</td>
#         <td>Lima – México DF - Cancún</td>
#     </tr>
#     <tr>
#         <td>LA</td>
#         <td>LAN</td>
#         <td>630</td>
#         <td>Lima - Cancún</td>
#     </tr>
#     <tr>
#         <td>TC</td>
#         <td>TACA</td>
#         <td>560</td>
#         <td>Lima – Bogotá – México DF - Cancún</td>
#     </tr>
# </table>
#
#
# COSTO DE ALOJAMIENTO
#
# <table>
#     <tr>
#         <td>CODIGO</td>
#         <td>TIPO</td>
#         <td>ALOJAMIENTO</td>
#         <td>PRECIO x DIA $</td>
#     </tr>
#     <tr>
#         <td>A001</td>
#         <td>Resort</td>
#         <td>Catalonia</td>
#         <td>273</td>
#     </tr>
#     <tr>
#         <td>A002</td>
#         <td>Resort</td>
#         <td>Hard Rock</td>
#         <td>260</td>
#     </tr>
#     <tr>
#         <td>A003</td>
#         <td>Hotel</td>
#         <td>West In</td>
#         <td>135</td>
#     </tr>
#     <tr>
#         <td>A004</td>
#         <td>Hotel</td>
#         <td>Paradise</td>
#         <td>140</td>
#     </tr>
#     <tr>
#         <td>A005</td>
#         <td>Motel</td>
#         <td>Motel Five</td>
#         <td>65</td>
#     </tr>
#       <tr>
#         <td>A006</td>
#         <td>Motel</td>
#         <td>Carmelita</td>
#         <td>70</td>
#     </tr>
# </table>
#
#
# COSTO DE TICKETS A PARQUES
# <table>
#     <tr>
#         <td>CODIGO</td>
#         <td>PARQUE</td>
#         <td>PRECIO x PERSONA $</td>
#     </tr>
#     <tr>
#         <td>XCA</td>
#         <td>XCARET</td>
#         <td>88</td>
#     </tr>
#     <tr>
#         <td>CHI</td>
#         <td>CHICHEN ITZA</td>
#         <td>317</td>
#     </tr>
#     <tr>
#         <td>XPL</td>
#         <td>XPLOR</td>
#         <td>140</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>545</td>
#     </tr>
# </table>
#
# Elaborar el programa que costee el paquete considerando los 3 componentes y adicionalmente la cantidad de personas a considerar en el paquete. Considerar que en todos los casos se debe indicar el codigo del item a seleccionar
# + Calcular el costo de pasajes ida y vuela(2 puntos)
# + Calcular el costo del alojamiento(4 puntos)
# + Calcular el costo de visitar los 3 parques(2 puntos)
# + Calcular el costo del paquete(2 puntos)

# %%
def costoPasajes(codigo, pasajeros)
  costo=0


  return costo*pasajeros
end

def costoAlojamiento(codigo, dias, pasajeros)
	#el costo del alojamiento considera el tipo , cantidad de dias y cant de pasajeros
    costo=0
 
   return costo*dias*pasajeros
end 


def costoParques(cantidad)
#el paquete incluye todos los parques
paquete = 0

return paquete 
end

def costoPaquete(costoPasajes,costoAlojamiento,costoParques)
#Asumiendo que ya tienen los costos de cada componente del paquete
costoPaquete=0
 


return costoPaquete
end	

#--- zona de test ----
def validate (expected, value)
 expected == value ? "." : "F"
end

def test_costoPasajes
	puts"Pasajes"
    print validate(1120, costoPasajes("TC",2)) 
	print validate(1890, costoPasajes("LA",3)) 
	print validate(2900, costoPasajes("MX",5)) 
	puts ""
end


 def test_costoAlojamiento
	puts  "Alojamiento"
    print validate(2730,costoAlojamiento("A001",5,2)) 
    print validate(810,costoAlojamiento("A003",3,2)) 
    print validate(280,costoAlojamiento("A006",2,2)) 
    puts ""
	
 end	

def test_costoParques
puts  "Parques"
print validate(2725,costoParques(5))
print validate(1635,costoParques(3))
print validate(1090,costoParques(2))
puts ""
end	

def test_costoPaquete
	puts "Costo del paquete"
	print validate(6575,costoPaquete(costoPasajes("TC",2),costoAlojamiento("A001",5,2),costoParques(5)))
	print validate(4335,costoPaquete(costoPasajes("LA",3),costoAlojamiento("A003",3,2),costoParques(3)))
	print validate(4270,costoPaquete(costoPasajes("MX",5),costoAlojamiento("A006",2,2),costoParques(2)))
    puts ""
end


def test
 
  puts "Test de prueba del programa"
  puts "---------------------------"
  test_costoPasajes
  test_costoAlojamiento
  test_costoParques
  test_costoPaquete
  puts " "
 end
test
# Out:
# Test de prueba del programa
# ---------------------------
# Pasajes
# FFF
# Alojamiento
# FFF
# Parques
# FFF
# Costo del paquete
# FFF

# %% [markdown]
# #### Contactanos
# ![https://www.facebook.com/instructorenprogramacion/](qr.png "https://www.facebook.com/instructorenprogramacion/")
