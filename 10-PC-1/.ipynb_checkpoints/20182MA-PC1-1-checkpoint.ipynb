# %% [markdown]
# ## Caso Demo 1: Práctica 1 - Uso de Sentencias Selectivas
# En los últimos años las empresas se ven en la necesidad de contar con soluciones informáticas más seguras, flexibles, escalables y que estén siempre disponibles a sus clientes. Las empresas peruanas no son ajenas a esta necesidad y están buscando alternativas de servicios en la nube (cloud) para alojar sus sistemas informáticos.
# En la siguiente tabla se muestran las principales empresas que brindan servicios en la nube y los costos de sus paquetes anuales en servidores.
#
# <table>
#     <tr>
#         <th>Tipo Servidor</th>
#         <th> Amazon </th>
#         <th> Azure </th>
#         <th> Softlayer </th>
#     </tr>
#     <tr>
#       <td>Dedicado</td>
#       <td>2400</td>
#       <td>2280</td>
#       <td>2340</td>
#     </tr>
#     <tr>
#       <td>Virtual</td>
#       <td>1440</td>
#       <td>1416</td>
#       <td>1428</td>
#     </tr>
#     <tr>
#       <td>Almacenamiento</td>
#       <td>960</td>
#       <td>1020</td>
#       <td>1080</td>
#     </tr>
# </table>
#
# Además de estos paquetes, también ofrecen licencias anuales de sistemas operativos:
# <table>
#     <tr>
#         <th>Licencia</th>
#         <th> Precio</th>
#     </tr>
#     <tr>
#       <td>WINDOWS</td>
#       <td>1620</td>
#     </tr>
#     <tr>
#       <td>LINUX</td>
#       <td>1200</td>
#     </tr>
#     <tr>
#       <td>UNIX</td>
#       <td>3240</td>
#     </tr>
# </table>
#
#
# Se le solicita lo siguiente:
#
# 1.	Dado un tipo de paquete anual de servidores y una empresa, determinar el precio de un paquete anual. (5 puntos)
# 2.	Dado un tipo de licencia, determinar el precio de venta anual. (2 puntos)
# 3.	Dado un tipo de paquete anual, una empresa y licencia, determinar el precio de venta mensual. (3 puntos)

# %%
def calcularPaqueteLicencia(licencia)

end

def calcularPaqueteServidores(paquete, empresa)

end

def calcularTotal(paquete, empresa, licencia)

end

#--- zona de test ----

def test_calcularPaqueteLicencia
    print validate(1620, calcularPaqueteLicencia("WINDOWS")) 
	print validate(1200, calcularPaqueteLicencia("LINUX")) 
	print validate(3240, calcularPaqueteLicencia("UNIX"))
    print validate(1020, calcularPaqueteLicencia("WINDOWS")) 
	print validate(1020, calcularPaqueteLicencia("LINUX")) 
	print validate(1020, calcularPaqueteLicencia("UNIX")) 
end

def test_calcularPaqueteServidores
    print validate(2400, calcularPaqueteServidores("Dedicado", "Amazon")) 
	print validate(1416, calcularPaqueteServidores("Virtual", "Azure")) 
	print validate(1080, calcularPaqueteServidores("Almacenamiento", "SoftLayer")) 
    print validate(2280, calcularPaqueteServidores("Dedicado", "Amazon")) 
	print validate(1440, calcularPaqueteServidores("Virtual", "Azure")) 
	print validate(1020, calcularPaqueteServidores("Almacenamiento", "SoftLayer")) 
end

def test_calcularTotal
    print validate(470, calcularTotal("Dedicado", "Amazon", "UNIX")) 
	print validate(325, calcularTotal("Dedicado", "Azure", "WINDOWS")) 
    print validate(190, calcularTotal("Almacenamiento", "SoftLayer", "LINUX")) 
    print validate(219, calcularTotal("Virtual", "SoftLayer", "UNIX")) 
end

def validate (expected, value)
    expected == value ? "." : "F"
end

def test
    puts " "
    puts "Test de prueba del programa"
    puts "---------------------------"
    puts " "
    puts "Enunciado - Paquete Servidores"
    test_calcularPaqueteServidores
    puts " "
    puts "Enunciado - Licencias"
    test_calcularPaqueteLicencia
    puts " "
    puts "Enunciado - Total mensual"
    test_calcularTotal
    puts " "
end
test

# %% [markdown]
# #### Contactanos
# ![https://www.facebook.com/instructorenprogramacion/](qr.png "https://www.facebook.com/instructorenprogramacion/")
