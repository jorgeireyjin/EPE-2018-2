# %% [markdown]
# ## Caso Demo 3: Práctica 1 - Uso de Sentencias Selectivas
# Empanaditas Café aplica unas promociones para impulsar la venta de los nuevos sabores que piensan lanzar y para ello está realizando diferentes simulaciones y así poder evaluar los resultados que podría esperar por parte de los clientes.
#
# Los nuevos sabores que forman parte de este nuevo lanzamiento son sabores oriundos del Perú. Para ello se deben considerar algunos valores mostrados a continuación
#
# Tamaño de la Porción
# <table>
#   <tr>
#     <td>Sabor</td>
#     <td>Pequeña</td>
#     <td>Mediana</td>
#     <td>Grande</td>
#   </tr>
#   <tr>
#     <td>Criollasa</td>
#     <td>S/ 4.50</td>
#     <td>S/ 7.80</td>
#     <td>S/ 15.70</td>
#   </tr>
#   <tr>
#     <td>Ají de gallina</td>
#     <td>S/ 5.00</td>
#     <td>S/ 8.50</td>
#     <td>S/ 17.90</td>
#   </tr>
#   <tr>
#     <td>Lomito</td>
#     <td>S/ 4.90</td>
#     <td>S/ 9.00</td>
#     <td>S/ 16.50</td>
#   </tr>
# </table>
#
#
# Asimismo, se tiene otro cuadro que contiene el descuento obtenido si es que un cliente compra más de una unidad y solo hasta 4, de cualquiera de los nuevos productos.
#
#   <table>
#   <tr>
#     <td></td>
#     <td>2</td>
#     <td>3</td>
#     <td>4</td>
#   </tr>
#   <tr>
#     <td>Descuento por cantidad</td>
#     <td>0.5%</td>
#     <td>1.2%</td>
#     <td>2.5%</td>
#   </tr>
#   </table>
#
#   Se pide desarrollar un programa que realice lo siguiente:
#
# 1.	Obtener el precio de cada empanada en base al sabor elegido y al tamaño de esta (4 puntos)
# 2.	Obtener el descuento obtenido de acuerdo con la cantidad comprada. ( 4 puntos )
# 3.	Obtener el precio total a pagar por el cliente, considerando que el cliente puede recibir un descuento por la cantidad comprada de un sabor. (2 puntos)

# %%
#encoding:UTF-8
def obtenerPrecioUnitario(sabor,presentacion)

   
end

def obtenerDescuentoPorCantidad(cantidad)

end

def costoTotal(sabor,presentacion,cantidad)

  return costo.round(2)

end

#--- zona de test ----

def test_obtenerPrecioUntario  
  print validate(4.50, obtenerPrecioUnitario("Criollasa","Pequeña"))
  print validate(17.90, obtenerPrecioUnitario("Aji de gallina","Grande"))
  print validate(9.00, obtenerPrecioUnitario("Lomito","Mediana"))  	
end

def test_obtenerDescuentoPorCantidad
    print validate(0.50, obtenerDescuentoPorCantidad(2)) 
    print validate(2.50, obtenerDescuentoPorCantidad(4)) 
    print validate(0.00, obtenerDescuentoPorCantidad(1)) 
end

def test_costoTotal
    print validate(46.77, costoTotal("Criollasa","Grande",3)) 
    print validate(16.92, costoTotal("Aji de gallina","Mediana",2)) 
    print validate(4.90, costoTotal("Lomito","Pequeña",1)) 
    print validate(17.55, costoTotal("Criollasa", "Pequeña",4)) 
end

def validate (expected, value)
 expected == value ? "." : "F"
end

def test
   
  puts "Test de prueba del programa"
  puts "---------------------------"
  test_obtenerPrecioUntario
  puts " "
  test_obtenerDescuentoPorCantidad
  puts " "
  test_costoTotal
  puts " "
end
test

# %% [markdown]
# #### Contactanos
# ![https://www.facebook.com/instructorenprogramacion/](qr.png "https://www.facebook.com/instructorenprogramacion/")
