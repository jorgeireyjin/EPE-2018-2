# %% [markdown]
# ### Pregunta 3
#
# Una cadena de pizzería lanza una promoción de sus tres principales productos, en tamaño familiar y por un día en particular de la semana. Los precios están en la siguiente tabla:
#
# <table>
#     <tr>
#         <th></th>
#         <th>Americana</th>
#         <th>Pepperoni</th>
#         <th>Suprema</th>
#     </tr>
#     <tr>
#         <td>Martes y jueves</td>
#         <td>20.00</td>
#         <td>25.00</td>
#         <td>40.00</td>
#     </tr>
#     <tr>
#         <td>Lunes, miércoles y viernes</td>
#         <td>25.50</td>
#         <td>30.50</td>
#         <td>45.00</td>
#     </tr>
#     <tr>
#         <td>Sábado y Domingos</td>
#         <td>28.50</td>
#         <td>25.00</td>
#         <td>55.50</td>
#     </tr>
# </table>
#
# Adicionalmente, se ofrece combos de bebidas con los siguientes valores
#
# <table>
#     <tr>
#         <th></th>
#         <th>Precio (S/.)</th>
#     </tr>
#     <tr>
#         <td>Combo1</td>
#         <td>10.00</td>
#     </tr>
#     <tr>
#         <td>Combo2</td>
#         <td>14.50</td>
#     </tr>
#     <tr>
#         <td>Combo3</td>
#         <td>17.50</td>
#     </tr>
#     <tr>
#         <td>Combo4</td>
#         <td>19.00</td>
#     </tr>
# </table>
#
# Se pide lo siguiente:
# 1.	Dado un día de la semana y un tipo de pizza, determinar el precio a pagar.
# 2.	Dado un tipo de combo, determinar el precio a pagar.
# 3.	Si el cliente tiene cupón de descuento del 5% sobre el monto total a pagar. Determinar el monto a pagar si un cliente quiere una pizza más combo.

# %%
def calcularPrecioPizza(tipoPizza, dia)

end

def calcularPrecioCombo(combo)

end

def calcularPrecioTotal(tipoPizza, dia, tipoCombo, tieneCupon)

end

#--- zona de test ----

def test_calcularPrecioPizza
  print validate(20.00, calcularPrecioPizza("Americana","Martes")) 
  print validate(25.00, calcularPrecioPizza("Pepperoni","Jueves")) 
  print validate(45.00, calcularPrecioPizza("Suprema","Miercoles")) 
  print validate(25.00, calcularPrecioPizza("Pepperoni","Domingo")) 
  print validate(45.00, calcularPrecioPizza("Suprema","Viernes"))   
end

def test_calcularPrecioCombo
  print validate(10.00, calcularPrecioCombo("Combo1")) 
  print validate(14.50, calcularPrecioCombo("Combo2")) 
  print validate(17.50, calcularPrecioCombo("Combo3")) 
  print validate(19.00, calcularPrecioCombo("Combo4")) 
end

def test_calcularPrecioTotal
  print validate(30.00, calcularPrecioTotal("Americana","Jueves", "Combo1",false)) 
  print validate(69.35, calcularPrecioTotal("Suprema","Domingo", "Combo3",true)) 
  print validate(49.50, calcularPrecioTotal("Pepperoni","Lunes", "Combo4",false)) 
end

def validate (expected, value)
 expected == value ? "." : "F"
end

def test
 
  puts "Test de prueba del programa"
  puts "---------------------------"
  test_calcularPrecioPizza
  test_calcularPrecioCombo
  test_calcularPrecioTotal
  puts " "
  
end
test
# Out:
# Test de prueba del programa
# ---------------------------
# FFFFFFFFFFFF
