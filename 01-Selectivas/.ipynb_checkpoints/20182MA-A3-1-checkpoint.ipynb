# %% [markdown]
# ### Pregunta 1
#
# Una tienda virtual ofrece las siguientes promociones en dólares por licencias de usuario:
# <table>
#     <tr>
#         <th></th>
#         <th>Software A</th>
#         <th>Software B</th>
#         <th>Software C</th>
#     </tr>
#     <tr>
#         <td>Hasta 500</td>
#         <td>100</td>
#         <td>1000</td>
#         <td>850</td>
#     </tr>
#     <tr>
#         <td>501 a 5000</td>
#         <td>600</td>
#         <td>4300</td>
#         <td>3600</td>
#     </tr>
#     <tr>
#         <td>5001 a más</td>
#         <td>1200</td>
#         <td>8700</td>
#         <td>7200</td>
#     </tr>
# </table>
#
# Adicionalmente, para aquellos que deseen un antivirus:
#
# <table>
#     <tr>
#         <th></th>
#         <th>Precio</th>
#     </tr>
#     <tr>
#         <td>Antivirus M</td>
#         <td>60</td>
#     </tr>
#     <tr>
#         <td>Antivirus X</td>
#         <td>125</td>
#     </tr>
#     <tr>
#         <td>Antivirus Z</td>
#         <td>90</td>
#     </tr>
# </table>
#
# Se pide lo siguiente:
# 1.	Dada una cantidad y tipo de software, mostrar el monto a pagar.
# 2.	Dado un tipo de antivirus, determinar el monto a pagar.

# %%
def calcularPrecioSoftware(tipoSoftware, licencias)

   
end

def calcularPrecioAntivirus(antivirus)

end

#--- zona de test ----

def test_calcularPrecioSoftware
  print validate(1000, calcularPrecioSoftware("SoftwareB", 200)) 
  print validate(1200, calcularPrecioSoftware("SoftwareA", 8000)) 
  print validate(3600, calcularPrecioSoftware("SoftwareC", 708)) 
end

def test_calcularPrecioAntivirus
    print validate(60, calcularPrecioAntivirus("Antivirus M")) 
  print validate(125, calcularPrecioAntivirus("Antivirus X")) 
  print validate(90, calcularPrecioAntivirus("Antivirus Z")) 
end

def validate (expected, value)
 expected == value ? "." : "F"
end

def test
 
  puts "Test de prueba del programa"
  puts "---------------------------"
  test_calcularPrecioSoftware
  test_calcularPrecioAntivirus
  puts " "
  
end
test
# Out:
# Test de prueba del programa
# ---------------------------
# FFFFFF
