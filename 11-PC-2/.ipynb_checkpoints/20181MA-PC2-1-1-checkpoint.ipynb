# %% [markdown]
# ### Pregunta 1 (10 puntos)
#
# Se tiene información del programa de datos abiertos relacionada a Educación Inclusiva, la información muestra la cantidad de alumnos con las principales discapacidades
#
# ![cuadro 1](20181MA-PC2-1-1.jpg "cuadro 1")
#
# Se pide lo siguiente:
#
# <ol>
# <li>Subprograma que obtenga el total de la población con un tipo de discapacidad (intelectual, sordera, ceguera , etc) (3 puntos)</li>
# <li>Subprograma que teniendo como dato los tipos de discapacidad pueda dar la región con la mayor  cantidad de estudiantes (3 puntos)</li>
# <li>Subprograma que dado un número  límite de alumnos con discapacidad, pueda mostrar en un arreglo las regiones que exceden ese límite (4 puntos)</li>
# </ol>

# %%
def poblacion(tipo)

end

def  mayorventa(tienda )
end

def regionesLimite(limite, grupo)

end


#--- zona de test ----


def test_pregunta1
print validate(10266,poblacion(@intelectual))
print validate(1146, poblacion(@auditiva))
print validate(604, poblacion(@visual))
print validate(60, poblacion(@sordoceguera))
end

def  test_pregunta2
print validate(3811,mayorventa(@intelectual))
print validate(537,mayorventa(@auditiva))
print validate(288,mayorventa(@visual))
print validate(18,mayorventa(@sordoceguera))
end 


def  test_pregunta3
print validate([642,621,474,617,3811,431,410],regionesLimite(400,@intelectual))
print validate([537],regionesLimite(400,@auditiva))
print validate([288],regionesLimite(200,@visual))
end


def validate (expected, value)
 expected == value ? "." : "F"
end
@region=["AMAZONAS","ANCASH","APURÍMAC","AREQUIPA","AYACUCHO","CAJAMARCA","CALLAO","CUSCO","HUANCAVELICA","HUÁNUCO","ICA","JUNÍN","LA LIBERTAD","LAMBAYEQUE","LIMA METROPOLITANA","LIMA PROVINCIAS","LORETO","MADRE DE DIOS","MOQUEGUA","PASCO","PIURA","PUNO","SAN MARTÍN","TACNA","TUMBES","UCAYALI"]

@intelectual=[55,365,157,642,146,195,621,474,179,198,244,256,617,190,3811,431,410,19,79,92,314,215,143,150,135,128]
@auditiva=[26,17,12,48,8,19,43,55,5,4,14,8,48,41,537,11,45,0,3,13,114,9,21,9,10,26]
@visual=[5,12,7,87,8,6,3,10,14,4,9,13,11,11,288,11,32,1,1,4,17,7,23,1,7,12]
@sordoceguera=[0,0,0,0,0,0,0,2,1,0,1,1,4,0,10,2,3,0,0,0,11,2,4,0,18,1]


puts "------Pregunta 1--------" 
puts ""
puts "------Prueba de total de población por tipo--------" 
test_pregunta1
puts ""
puts "------Prueba de región con mayor cantidad de estudiantes--------" 
test_pregunta2
puts ""
puts "------Prueba consulta por limite de alumnos por región--------" 
test_pregunta3
puts ""
# Out:
# ------Pregunta 1--------
#
# ------Prueba de total de población por tipo--------
# FFFF
# ------Prueba de región con mayor cantidad de estudiantes--------
# FFFF
# ------Prueba consulta por limite de alumnos por región--------
# FFF

# %% [markdown]
# ### Pregunta 2 (10 puntos)
#
# El programa de datos abiertos tiene las estadísticas de colegios que brindan educación inclusiva por región y nivel de educación
#
# Se solicita lo siguiente:
#
# ![cuadro 2](20181MA-PC2-1-2.jpg "cuadro 2")
#
# <ol>
# <li>Subprograma que devuelva una matriz con  la cantidad total de colegios por región (inicial, primaria y secundaria) (3 puntos)</li>
# <li>Subprograma que devuelva la región con la mayor población de estudiantes de un determinado tipo (3 ptos)</li>
# <li>Subprograma que devuelva la cantidad  con el déficit de cantidad de sitios  que serán necesarios para atender la demanda de alumnos   cuando pasen de primaria a secundaria en una determinada región  ( 4 puntos)</li>
# </ol>

# %%
def totalcolegiosRegion(region,regiones,inicial,primaria,secundaria)

end

def  regionMayorpoblacion(region, tipo )

end

def deficitAlumnos(nombregion,region, primaria,secundaria)

end


#--- zona de test ----


def test_pregunta1
print validate(424,totalcolegiosRegion("AMAZONAS",@region,@inicial,@primaria,@secundaria))
print validate(607,totalcolegiosRegion("AREQUIPA",@region,@inicial,@primaria,@secundaria))
print validate(1056,totalcolegiosRegion("CAJAMARCA",@region,@inicial,@primaria,@secundaria))
print validate(407,totalcolegiosRegion("ICA",@region,@inicial,@primaria,@secundaria))
end

def  test_pregunta2
print validate("LIMA METROPOLITANA",regionMayorpoblacion(@region,@inicial))
print validate("LIMA METROPOLITANA",regionMayorpoblacion(@region,@primaria))
print validate("LIMA METROPOLITANA",regionMayorpoblacion(@region,@secundaria))
end 


def  test_pregunta3
print validate(-154, deficitAlumnos("ICA",@region,@primaria,@secundaria))
print validate(-247, deficitAlumnos("AYACUCHO",@region,@primaria,@secundaria))
print validate(-407, deficitAlumnos("CUSCO",@region,@primaria,@secundaria))
end


def validate (expected, value)
 expected == value ? "." : "F"
end
@region=["AMAZONAS","ANCASH","APURÍMAC","AREQUIPA","AYACUCHO","CAJAMARCA","CALLAO","CUSCO","HUANCAVELICA","HUÁNUCO","ICA","JUNÍN","LA LIBERTAD","LAMBAYEQUE","LIMA METROPOLITANA","LIMA PROVINCIAS","LORETO","MADRE DE DIOS","MOQUEGUA","PASCO","PIURA","PUNO","SAN MARTÍN","TACNA","TUMBES","UCAYALI"]
@inicial=[64,164,85,139,106,148,89,153,77,87,125,105,201,102,778,96,54,15,40,29,197,181,106,28,28,27]
@primaria=[294,504,281,336,341,739,155,565,347,339,218,442,442,296,1179,299,155,40,61,132,620,	613,328,68,46,83]
@secundaria=[66,146,103,132,94,169,63,158,99,80,64,111,145,99,577,89,41,19,28,50,242,175,79,41,30,22]

puts "------Prueba de total de población por region--------" 
test_pregunta1
puts ""
puts "------Prueba de región con mayor cantidad de estudiantes--------" 
test_pregunta2
puts ""
puts "------Prueba deficit de colegios región--------" 
test_pregunta3
puts ""
# Out:
# ------Prueba de total de población por region--------
# FFFF
# ------Prueba de región con mayor cantidad de estudiantes--------
# FFF
# ------Prueba deficit de colegios región--------
# FFF
